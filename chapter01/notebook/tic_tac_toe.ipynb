# %% [markdown]
# # RLAI - Chapter 1
#
# ## An extended example: Tic-Tac-Toe

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
import json

import numpy as np

# %%
NMARKS = 3
BOARD_NROWS = BOARD_NCOLS = 3
BOARD_SIZE = BOARD_NROWS * BOARD_NCOLS

CROSS = 1
CIRCLE = -1
EMPTY = 0

# %%
def hash(board):
    return ','.join([str(x) for x in list(board.reshape(BOARD_SIZE))])

# %%
class Environment:
    """Environment class for Tic-Tac Toe."""

    def __init__(self):
        self.steps_left = BOARD_SIZE
        self.board = (np.array([EMPTY] * BOARD_SIZE)
                        .reshape((BOARD_NROWS, BOARD_NCOLS)))
        self.state = hash(self.board)
        self.winner = EMPTY

    def get_positions(self):
        """Get possible action positions given current board."""
        positions = []
        for r in range(BOARD_NROWS):
            for c in range(BOARD_NCOLS):
                if self.board[r][c] == EMPTY:
                    positions.append((r, c))
        return positions

    def _judge(self):
        """Judge winner based on the current board."""
        # Check rows.
        for r in range(BOARD_NROWS):
            row = self.board[r, :]
            symbol = row[0]
            if symbol != EMPTY and np.sum(row) == symbol * NMARKS:
                self.winner = symbol
                self.steps_left = 0
                return self

        # Check columns.
        for c in range(BOARD_NCOLS):
            col = self.board[:, c]
            symbol = col[0]
            if symbol != EMPTY and np.sum(col) == symbol * NMARKS:
                self.winner = symbol
                self.steps_left = 0
                return self

        # Check diagonals.
        mid = BOARD_NROWS // 2
        symbol = self.board[mid][mid]
        if symbol != EMPTY: 
            diag1, diag2 = [], []
            for i in range(BOARD_NROWS):
                diag1.append(self.board[i][i])
                diag2.append(self.board[i][BOARD_NROWS - i - 1])

            diag1, diag2 = np.array(diag1), np.array(diag2)
            if (np.sum(diag1) == symbol * NMARKS or 
                np.sum(diag2) == symbol * NMARKS):
                self.winner = symbol
                self.steps_left = 0
                return self

    def is_done(self):
        """Check the game is done."""
        return self.steps_left == 0

    def step(self, r, c, symbol):
        """Take a step with symbol."""
        env_next = self._copy()
        env_next.board[r][c] = symbol
        env_next.state = hash(env_next.board)
        env_next.steps_left -= 1
        env_next._judge()
        return env_next

    def _copy(self):
        """Copy to a new Environment instance."""
        env_copy = Environment()
        env_copy.steps_left = self.steps_left
        env_copy.board = self.board.copy()
        env_copy.state = self.state
        env_copy.winner = self.winner
        return env_copy

    def show_board(self):
        """Show board."""
        board = self.board.tolist()
        for r in range(BOARD_NROWS):
            for c in range(BOARD_NCOLS):
                if board[r][c] == CROSS:
                    board[r][c] = 'X'
                elif board[r][c] == CIRCLE:
                    board[r][c] = 'O'
                else:
                    board[r][c] = ' '

        print('Board: is_done={}, steps_left={}, winner={}'
              .format(self.is_done(), self.steps_left, self.winner))
        for r in range(BOARD_NROWS):
            print(board[r])

# %%
def _dfs_states(cur_symbol, env, all_state_env_d):
    """DFS for next state by recursion."""
    for r in range(BOARD_NROWS):
        for c in range(BOARD_NCOLS):
            if env.board[r][c] == EMPTY:
                env_next = env.step(r, c, cur_symbol)
                if env_next.state not in all_state_env_d:
                    all_state_env_d[env_next.state] = env_next

                    # If game is not ended, continue DFS.
                    if not env_next.is_done():
                        _dfs_states(-cur_symbol, env_next, all_state_env_d)

def get_all_states():
    """Get all states from the init state."""
    # The player who plays first always uses 'X'.
    cur_symbol = CROSS

    # Apply DFS to collect all states.
    env = Environment()
    all_state_env_d = dict()
    all_state_env_d[env.state] = env
    _dfs_states(cur_symbol, env, all_state_env_d)
    return all_state_env_d

# %%
ALL_STATE_ENV_D = get_all_states()

# %%
# ALL_STATE_ENV_D

# %%
# s = '1,-1,1,-1,-1,1,1,1,-1'
# print(ALL_STATE_ENV_D[s].winner)
# print(ALL_STATE_ENV_D[s].steps_left)

# %%
# env = Environment()
# env.__dict__
# print(env.board)
# print(env.winner)

# %%
# env = env.step(1, 1, 1)
# print(env.board)
# print(env.winner)

# %%
# env = env.step(0, 0, -1)
# print(env.board)
# print(env.winner)

# %%
# for s, env in ALL_STATE_ENV_DICT.items():
#     if env.winner == CIRCLE:
#         env.show_board()
#         print('=>', env.winner, env.is_done(), env.steps_left)

# %%
class Agent:
    """Agent class for Tic-Tac-Toe game."""

    def __init__(self, player='X', step_size=0.01, epsilon=0.01):
        self.player = player
        if self.player == 'X':
            self.symbol = CROSS
        elif self.player == 'O':
            self.symbol = CIRCLE
        else:
            raise InputError("Input player should be 'X' or 'O'")

        self.step_size = step_size
        self.epsilon = epsilon

        # Create a state-value table V:state->value.
        self.V = dict()

        # Memoize action state, its parent state & is_greedy bool:
        # state_parent_d:state->parent state & state_isgreedy_d:state->is_greedy bool.
        self.states = []
        self.state_parent_d = dict()
        self.state_isgreedy_d = dict()

    def init_state_value_table(self):
        """Init state-value table."""
        all_state_env_d = ALL_STATE_ENV_D

        for s, env in all_state_env_d.items():
            if env.winner == self.symbol:
                # If agent is winner, it gets reward 1.
                self.V[s] = 1.0
            elif env.winner == -self.symbol or env.steps_left == 0:
                # If agent is loser or tied, it gets reward 0.
                self.V[s] = 0.0
            else:
                # For other cases, agent get reward 0.5.
                self.V[s] = 0.5

    def reset_episode(self, env):
        """Init episode."""
        self.states.append(env.state)
        self.state_parent_d[env.state] = None
        self.state_isgreedy_d[env.state] = False

    def _exploit_and_explore(self, env, positions):
        """Exploit and explore by the epsilon-greedy strategy:
          - Take exploratory moves in the p% of times. 
          - Take greedy moves in the (100-p)% of times.
        where p% is epsilon. 
        If epsilon is zero, then use the greedy strategy.
        """
        vals_positions = []
        for (r, c) in positions:
            env_next = env.step(r, c, self.symbol)
            s = env_next.state
            v = self.V[s]
            vals_positions.append((v, (r, c)))

        p = np.random.random()
        if p > self.epsilon:
            # Exploit by selecting the move with the greatest value,
            # breaking ties randomly.
            np.random.shuffle(vals_positions)
            vals_positions.sort(key=lambda x: x[0], reverse=True)
            (r, c) = vals_positions[0][1]
            is_greedy = True
        else:
            # Explore by selecting randomly from among moves.
            n = len(vals_positions)
            (r, c) = vals_positions[np.random.randint(n)][1]
            is_greedy = False

        env_next = env.step(r, c, self.symbol)
        state_next = env_next.state
        return (r, c, state_next, is_greedy)

    def add_state(self, state_next, is_greedy):
        state = self.states[-1]
        self.state_parent_d[state_next] = state
        self.state_isgreedy_d[state_next] = is_greedy
        self.states.append(state_next)
        return self

    def select_position(self, env):
        """Select a action position by the epsilon-greedy strategy.

        Agent gets candidate positions given current state.
        Then it selects a position by strategy.
        """
        # Get next action positions from environment.
        positions = env.get_positions()

        # Exloit and explore by the epsilon-greedy strategy.
        (r, c, state_next, is_greedy) = self._exploit_and_explore(
            env, positions)

        # Add state.
        self.add_state(state_next, is_greedy)
        return r, c, self.symbol

    def backup_state_value(self):
        """Back up value by a temporal-difference learning after a greedy move.

        Temporal-difference learning:
          V(S_t) <- V(S_t) + a * [V(S_{t+1}) - V(S_t)]
        where a is the step size, and V(S_t) is the state-value function
        at time step t.
        """
        s = self.states[-1]
        s_par = self.state_parent_d[s]
        is_greedy = self.state_isgreedy_d[s]
        if is_greedy:
            self.V[s_par] += self.step_size * (self.V[s] - self.V[s_par])

    def save_state_value_table(self):
        """Save learned state-value table."""
        if self.symbol == CROSS:
            json.dump(self.V, open("state_value_x.json", 'w'))
        else:
            json.dump(self.V, open("state_value_o.json", 'w'))

    def load_state_value_table(self):
        """Load learned state-value table."""
        if self.symbol == CROSS:
            self.V = json.load(open("state_value_x.json"))
        else:
            self.V = json.load(open("state_value_o.json"))

# %%
# agent1 = Agent(player='X', step_size=0.01, epsilon=0.01)
# agent1.reset_episode(env)

# %%
# agent1.__dict__

# %%
def self_train(epochs=100000, step_size=0.1, epsilon=0.1, print_per_epochs=100):
    """Self train an agent by playing games against itself."""
    agent1 = Agent(player='X', step_size=step_size, epsilon=epsilon)
    agent2 = Agent(player='O', step_size=step_size, epsilon=epsilon)
    agent1.init_state_value_table()
    agent2.init_state_value_table()

    n_agent1_wins = 0
    n_agent2_wins = 0
    n_ties = 0

    for i in range(1, epochs + 1):
        # Reset both agents after epoch was done.
        env = Environment()
        agent1.reset_episode(env)
        agent2.reset_episode(env)

        while not env.is_done():
            # Agent 1 plays one step.
            r1, c1, symbol1 = agent1.select_position(env)
            env = env.step(r1, c1, symbol1)
            agent1.backup_state_value()

            if env.is_done():
                break

            # Agent 2 plays the next step.
            r2, c2, symbol2 = agent2.select_position(env)
            env = env.step(r2, c2, symbol2)
            agent2.backup_state_value()

        # Set final state with is_greedy=True to backup value.
        is_greedy = True
        if env.winner == CROSS:
            agent2.add_state(env.state, is_greedy)
            agent2.backup_state_value()
            n_agent1_wins += 1
        elif env.winner == CIRCLE:
            agent1.add_state(env.state, is_greedy)
            agent1.backup_state_value()
            n_agent2_wins += 1
        else:
            n_ties += 1

        # Print board.
        if i % print_per_epochs == 0:
            print('Epoch {}: Agent1 wins {}, Agent2 wins {}, ties {}'
                  .format(i,
                          round(n_agent1_wins / i, 2), 
                          round(n_agent2_wins / i, 2), 
                          round(n_ties / i, 2)))
            env.show_board()
            print('---')

    agent1.save_state_value_table()
    agent2.save_state_value_table()

# %%
self_train(epochs=100000, step_size=0.1, epsilon=0.10, print_per_epochs=500)
# Out:
# Epoch 500: Agent1 wins 0.51, Agent2 wins 0.33, ties 0.15
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'X']
# [' ', 'X', 'O']
# ['O', ' ', 'O']
# ---
# Epoch 1000: Agent1 wins 0.45, Agent2 wins 0.31, ties 0.24
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 1500: Agent1 wins 0.4, Agent2 wins 0.35, ties 0.25
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'X']
# ['O', 'O', 'X']
# ['O', 'X', 'X']
# ---
# Epoch 2000: Agent1 wins 0.39, Agent2 wins 0.37, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# [' ', 'O', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 2500: Agent1 wins 0.37, Agent2 wins 0.4, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# [' ', ' ', 'O']
# ---
# Epoch 3000: Agent1 wins 0.34, Agent2 wins 0.43, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', ' ']
# ['O', 'O', 'O']
# ['X', ' ', 'X']
# ---
# Epoch 3500: Agent1 wins 0.31, Agent2 wins 0.45, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# ['X', 'X', 'O']
# [' ', ' ', 'O']
# ---
# Epoch 4000: Agent1 wins 0.3, Agent2 wins 0.47, ties 0.24
# Board: is_done=True, steps_left=0, winner=1
# ['O', ' ', 'X']
# ['O', 'X', ' ']
# ['X', ' ', ' ']
# ---
# Epoch 4500: Agent1 wins 0.28, Agent2 wins 0.48, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', ' ']
# ['O', 'O', 'O']
# [' ', 'X', 'X']
# ---
# Epoch 5000: Agent1 wins 0.27, Agent2 wins 0.5, ties 0.24
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 5500: Agent1 wins 0.26, Agent2 wins 0.5, ties 0.24
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'O']
# ['O', 'O', 'X']
# ['X', 'X', 'X']
# ---
# Epoch 6000: Agent1 wins 0.25, Agent2 wins 0.51, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# ['X', 'X', 'O']
# ['X', 'O', 'O']
# ---
# Epoch 6500: Agent1 wins 0.25, Agent2 wins 0.51, ties 0.24
# Board: is_done=True, steps_left=0, winner=1
# [' ', 'O', 'X']
# [' ', 'O', 'X']
# ['O', 'X', 'X']
# ---
# Epoch 7000: Agent1 wins 0.24, Agent2 wins 0.52, ties 0.24
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 7500: Agent1 wins 0.24, Agent2 wins 0.52, ties 0.25
# Board: is_done=True, steps_left=0, winner=1
# [' ', 'X', 'O']
# [' ', 'X', 'O']
# [' ', 'X', ' ']
# ---
# Epoch 8000: Agent1 wins 0.23, Agent2 wins 0.52, ties 0.25
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', ' ']
# [' ', 'O', ' ']
# ['X', 'O', 'X']
# ---
# Epoch 8500: Agent1 wins 0.23, Agent2 wins 0.53, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# ['O', 'X', 'X']
# [' ', 'X', 'X']
# ---
# Epoch 9000: Agent1 wins 0.23, Agent2 wins 0.53, ties 0.24
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['X', 'X', 'O']
# [' ', 'O', 'O']
# ---
# Epoch 9500: Agent1 wins 0.22, Agent2 wins 0.53, ties 0.25
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'X']
# ['X', 'O', 'X']
# [' ', ' ', 'O']
# ---
# Epoch 10000: Agent1 wins 0.22, Agent2 wins 0.53, ties 0.25
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['X', 'O', ' ']
# [' ', 'X', 'O']
# ---
# Epoch 10500: Agent1 wins 0.22, Agent2 wins 0.53, ties 0.25
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 11000: Agent1 wins 0.22, Agent2 wins 0.54, ties 0.25
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', ' ']
# [' ', 'X', 'O']
# [' ', 'X', ' ']
# ---
# Epoch 11500: Agent1 wins 0.22, Agent2 wins 0.53, ties 0.25
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', ' ']
# ['O', 'X', 'X']
# ['O', 'X', ' ']
# ---
# Epoch 12000: Agent1 wins 0.21, Agent2 wins 0.54, ties 0.25
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', ' ']
# ['X', 'X', 'X']
# [' ', 'O', 'O']
# ---
# Epoch 12500: Agent1 wins 0.21, Agent2 wins 0.53, ties 0.26
# Board: is_done=True, steps_left=0, winner=1
# ['O', ' ', 'X']
# ['O', 'X', ' ']
# ['X', ' ', ' ']
# ---
# Epoch 13000: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.26
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'X']
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 13500: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.27
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'X']
# ['X', 'O', 'X']
# [' ', 'X', 'O']
# ---
# Epoch 14000: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.27
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# [' ', 'X', ' ']
# ---
# Epoch 14500: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.27
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['X', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 15000: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.27
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# [' ', 'X', ' ']
# ['X', ' ', 'X']
# ---
# Epoch 15500: Agent1 wins 0.21, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['O', 'X', 'X']
# ['O', ' ', ' ']
# ---
# Epoch 16000: Agent1 wins 0.21, Agent2 wins 0.51, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', ' ']
# ['X', 'X', 'O']
# ['O', 'O', 'O']
# ---
# Epoch 16500: Agent1 wins 0.21, Agent2 wins 0.51, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 17000: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'O', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 17500: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# [' ', 'O', ' ']
# ['O', 'X', 'X']
# ---
# Epoch 18000: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# ['X', 'X', ' ']
# [' ', ' ', 'X']
# ---
# Epoch 18500: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.28
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'X']
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 19000: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.28
# Board: is_done=True, steps_left=0, winner=1
# [' ', 'O', 'O']
# [' ', 'O', 'X']
# ['X', 'X', 'X']
# ---
# Epoch 19500: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'O', 'X']
# ['O', 'X', ' ']
# ['X', ' ', 'X']
# ---
# Epoch 20000: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# [' ', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 20500: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'X']
# ['X', 'O', ' ']
# ['X', ' ', 'O']
# ---
# Epoch 21000: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['X', 'X', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 21500: Agent1 wins 0.2, Agent2 wins 0.51, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# [' ', 'O', 'O']
# ['X', 'O', ' ']
# ['X', 'X', 'X']
# ---
# Epoch 22000: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 22500: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', ' ']
# [' ', 'O', 'X']
# ['X', 'O', ' ']
# ---
# Epoch 23000: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# ['X', 'O', 'X']
# [' ', 'O', 'O']
# ---
# Epoch 23500: Agent1 wins 0.2, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'O']
# [' ', 'O', 'X']
# ['O', 'X', ' ']
# ---
# Epoch 24000: Agent1 wins 0.2, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'O']
# ['X', 'O', ' ']
# ['O', 'X', 'X']
# ---
# Epoch 24500: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', ' ']
# [' ', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 25000: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'O']
# ['X', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 25500: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'X']
# ['X', 'O', ' ']
# ['O', ' ', 'O']
# ---
# Epoch 26000: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['X', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 26500: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.27
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', ' ']
# [' ', 'X', ' ']
# ['O', ' ', 'X']
# ---
# Epoch 27000: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.27
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', 'O']
# [' ', 'O', 'O']
# ['X', 'X', 'X']
# ---
# Epoch 27500: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 28000: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 28500: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'X']
# ['O', 'O', 'O']
# [' ', ' ', 'X']
# ---
# Epoch 29000: Agent1 wins 0.19, Agent2 wins 0.53, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 29500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 30000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 30500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.28
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['X', 'X', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 31000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 31500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# [' ', 'O', ' ']
# ['X', 'X', 'O']
# ---
# Epoch 32000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['O', ' ', ' ']
# ['X', 'X', 'X']
# [' ', 'O', ' ']
# ---
# Epoch 32500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 33000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 33500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'X']
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ---
# Epoch 34000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'X']
# ['O', 'O', 'O']
# ['X', ' ', ' ']
# ---
# Epoch 34500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 35000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'X']
# [' ', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 35500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'X']
# ['O', 'X', 'X']
# ['O', 'O', 'O']
# ---
# Epoch 36000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 36500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 37000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# ['X', 'O', ' ']
# ['O', ' ', 'X']
# ---
# Epoch 37500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 38000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 38500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# [' ', 'X', 'O']
# ---
# Epoch 39000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', ' ']
# ['X', 'O', ' ']
# ['X', 'X', 'O']
# ---
# Epoch 39500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# [' ', 'O', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 40000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', ' ']
# ['O', 'O', 'O']
# [' ', ' ', 'X']
# ---
# Epoch 40500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'O']
# [' ', 'O', ' ']
# ['O', 'X', 'X']
# ---
# Epoch 41000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', ' ']
# ['O', 'X', 'X']
# ['O', 'O', 'O']
# ---
# Epoch 41500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 42000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'O', 'X']
# [' ', 'X', ' ']
# ['X', 'X', 'O']
# ---
# Epoch 42500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['O', 'X', 'X']
# ['O', ' ', ' ']
# ---
# Epoch 43000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 43500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['X', 'O', 'O']
# ['O', 'X', ' ']
# ---
# Epoch 44000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# [' ', 'X', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 44500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# ['X', 'X', ' ']
# [' ', ' ', 'X']
# ---
# Epoch 45000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'O']
# ['X', 'X', 'X']
# ['O', 'O', 'X']
# ---
# Epoch 45500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', ' ', 'X']
# ['O', 'O', 'O']
# [' ', 'X', 'X']
# ---
# Epoch 46000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 46500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# [' ', ' ', ' ']
# [' ', 'O', 'O']
# ['X', 'X', 'X']
# ---
# Epoch 47000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'O']
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 47500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 48000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'O']
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 48500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# [' ', ' ', 'O']
# [' ', ' ', 'O']
# ['X', 'X', 'X']
# ---
# Epoch 49000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'X']
# [' ', 'O', 'X']
# ['O', ' ', 'O']
# ---
# Epoch 49500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 50000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# [' ', 'O', 'X']
# ['X', 'O', ' ']
# ---
# Epoch 50500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', ' ']
# ['O', 'O', 'O']
# ['X', ' ', 'X']
# ---
# Epoch 51000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['X', 'O', 'X']
# ['O', ' ', 'O']
# ---
# Epoch 51500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 52000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# ['X', 'O', 'O']
# ---
# Epoch 52500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'X']
# ['O', 'X', 'X']
# ['O', 'O', 'O']
# ---
# Epoch 53000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'X']
# ['O', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 53500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 54000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', ' ']
# ---
# Epoch 54500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# ['X', 'O', 'O']
# ---
# Epoch 55000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 55500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 56000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 56500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# ['O', 'O', 'X']
# ['X', 'O', ' ']
# ---
# Epoch 57000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 57500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', ' ']
# ['X', ' ', 'O']
# ['X', ' ', 'O']
# ---
# Epoch 58000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['X', 'O', 'O']
# ['O', 'X', ' ']
# ---
# Epoch 58500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# ['X', 'O', 'X']
# ['X', ' ', 'X']
# ---
# Epoch 59000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# [' ', ' ', ' ']
# ['O', ' ', 'O']
# ['X', 'X', 'X']
# ---
# Epoch 59500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'X']
# [' ', 'O', 'X']
# ['X', ' ', 'O']
# ---
# Epoch 60000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['O', 'O', 'O']
# ['X', ' ', 'X']
# ---
# Epoch 60500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 61000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 61500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# [' ', 'X', 'O']
# ---
# Epoch 62000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# ['X', 'O', 'O']
# ---
# Epoch 62500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', ' ']
# ['X', 'O', ' ']
# [' ', 'O', 'X']
# ---
# Epoch 63000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 63500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'O']
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 64000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# [' ', 'X', 'O']
# [' ', 'X', ' ']
# ['O', 'X', ' ']
# ---
# Epoch 64500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'X']
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 65000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', ' ', 'X']
# ['O', 'O', 'O']
# [' ', 'X', 'X']
# ---
# Epoch 65500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 66000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'X']
# ['O', 'O', 'O']
# [' ', ' ', 'X']
# ---
# Epoch 66500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['X', 'O', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 67000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# ['O', 'O', 'O']
# [' ', 'X', 'X']
# ---
# Epoch 67500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', ' ']
# ['O', 'X', ' ']
# [' ', 'O', 'X']
# ---
# Epoch 68000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', ' ']
# ['X', ' ', 'O']
# ---
# Epoch 68500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# [' ', ' ', 'O']
# ---
# Epoch 69000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', ' ']
# ['O', 'X', 'O']
# [' ', ' ', 'X']
# ---
# Epoch 69500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 70000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 70500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['O', 'O', 'O']
# ['X', 'X', ' ']
# ---
# Epoch 71000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# [' ', 'O', 'X']
# ['X', 'O', ' ']
# ---
# Epoch 71500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 72000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', 'O']
# ['X', ' ', ' ']
# ['X', ' ', 'O']
# ---
# Epoch 72500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', ' ']
# ['X', 'O', 'O']
# ['X', ' ', ' ']
# ---
# Epoch 73000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'X']
# ['O', 'X', 'X']
# ['O', 'O', 'O']
# ---
# Epoch 73500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 74000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# [' ', 'X', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 74500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 75000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 75500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'X']
# ['O', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 76000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'O', 'O']
# [' ', 'X', ' ']
# ['X', 'X', ' ']
# ---
# Epoch 76500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'X']
# ['O', 'O', 'X']
# [' ', ' ', 'X']
# ---
# Epoch 77000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', ' ']
# ---
# Epoch 77500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', ' ']
# ---
# Epoch 78000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'O']
# ['O', 'X', ' ']
# ['X', ' ', 'X']
# ---
# Epoch 78500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# [' ', ' ', 'O']
# ---
# Epoch 79000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# ['X', 'O', ' ']
# ['O', 'O', 'X']
# ---
# Epoch 79500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'X']
# ['X', 'O', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 80000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# [' ', 'O', 'X']
# [' ', ' ', 'O']
# ---
# Epoch 80500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', 'X']
# [' ', 'O', ' ']
# ---
# Epoch 81000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=1
# [' ', ' ', 'X']
# ['O', 'O', 'X']
# [' ', ' ', 'X']
# ---
# Epoch 81500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', 'X']
# ['O', 'X', ' ']
# ['O', ' ', 'X']
# ---
# Epoch 82000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', ' ']
# ---
# Epoch 82500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'O']
# ---
# Epoch 83000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 83500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'O']
# ['X', 'X', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 84000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'X', 'O']
# ['X', 'X', 'O']
# ['X', 'O', 'O']
# ---
# Epoch 84500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# [' ', 'X', 'O']
# ---
# Epoch 85000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'O']
# ['X', 'X', 'O']
# ['X', 'X', 'O']
# ---
# Epoch 85500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', ' ']
# ---
# Epoch 86000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# ['O', 'O', 'O']
# ['X', ' ', 'X']
# ---
# Epoch 86500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['X', 'O', 'O']
# ['O', ' ', 'X']
# ---
# Epoch 87000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# ['O', 'O', 'O']
# [' ', 'X', 'X']
# ---
# Epoch 87500: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# ['X', 'O', ' ']
# [' ', 'O', ' ']
# ---
# Epoch 88000: Agent1 wins 0.19, Agent2 wins 0.52, ties 0.29
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'O', 'X']
# ['X', 'O', ' ']
# [' ', 'O', ' ']
# ---
# Epoch 88500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', ' ', ' ']
# ['X', 'O', 'X']
# [' ', 'X', 'O']
# ---
# Epoch 89000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'O', 'X']
# ---
# Epoch 89500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'X', 'O']
# ['O', 'O', 'X']
# ---
# Epoch 90000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['X', 'O', 'X']
# ['O', 'X', 'X']
# ['O', 'X', 'O']
# ---
# Epoch 90500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 91000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# [' ', ' ', 'O']
# [' ', 'O', ' ']
# ['X', 'X', 'X']
# ---
# Epoch 91500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', ' ', 'O']
# ['X', 'O', ' ']
# ['X', 'X', 'O']
# ---
# Epoch 92000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', ' ', 'X']
# ['O', 'O', 'O']
# ['X', 'X', ' ']
# ---
# Epoch 92500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 93000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# ---
# Epoch 93500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'X']
# ['O', 'O', 'X']
# ['O', 'X', ' ']
# ---
# Epoch 94000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'O', 'X']
# ['X', 'O', 'O']
# ['X', ' ', ' ']
# ---
# Epoch 94500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 95000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', 'X', 'O']
# [' ', 'O', ' ']
# ['O', ' ', 'X']
# ---
# Epoch 95500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# [' ', 'O', 'X']
# [' ', 'X', 'O']
# ---
# Epoch 96000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', 'O']
# ['X', 'O', ' ']
# ['O', 'X', 'X']
# ---
# Epoch 96500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['O', ' ', 'X']
# ['X', 'X', 'O']
# ['X', ' ', 'O']
# ---
# Epoch 97000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['O', 'O', 'X']
# ['X', 'X', 'O']
# ---
# Epoch 97500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# [' ', 'O', ' ']
# ['X', 'O', 'X']
# ---
# Epoch 98000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# [' ', 'O', 'X']
# [' ', 'O', 'X']
# ['X', 'O', ' ']
# ---
# Epoch 98500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['X', ' ', 'X']
# ['O', 'O', 'O']
# ['X', ' ', ' ']
# ---
# Epoch 99000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=0
# ['O', 'X', 'X']
# ['X', 'O', 'O']
# ['X', 'O', 'X']
# ---
# Epoch 99500: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=1
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# ['O', 'X', 'X']
# ---
# Epoch 100000: Agent1 wins 0.19, Agent2 wins 0.51, ties 0.3
# Board: is_done=True, steps_left=0, winner=-1
# ['O', 'X', ' ']
# ['X', 'O', 'O']
# ['X', 'X', 'O']
# ---

# %%
class Human:
    """Human class for Tic-Tac-Toe game."""

    def __init__(self, player='X'):
        self.player = player
        if self.player == 'X':
            self.symbol = CROSS
        elif self.player == 'O':
            self.symbol = CIRCLE

    def select_position(self, env):
        """Select a position given current state."""
        # Get human input position.
        input_position_re = re.compile('^[0-2],[0-2]$')
        positions = set(env.get_positions())
        while True:
            input_position = input(
                'Please input position for {} in the format: "row,col" with '
                .format(self.player) +
                'row/col: 0~{}:\n'.format(BOARD_NROWS - 1))

            if not input_position_re.match(input_position):
                print('Input position style is incorrect!\n')
                continue

            input_position = tuple([int(x) for x in input_position.split(',')])
            if input_position in positions:
                break
            else:
                print('Input position was occupied, please input "row,col" again!\n')

        (r, c) = input_position
        return r, c, self.symbol

# %%
# env = Environment()
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
# agent1 = Agent(player='X', step_size=0.01, epsilon=0)
# agent1.reset_episode(env)
# agent1.load_state_values()

# %%
# agent1.V

# %%
# agent1.V['0,0,0,0,0,0,0,0,1']

# %%
# human = Human(player='O')

# %%
# r1, c1, symbol1 = agent1.play(env)
# env = env.step(r1, c1, symbol1)
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
# r2, c2, symbol2 = human.play(env)
# env = env.step(r2, c2, symbol2)
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
# r1, c1, symbol1 = agent1.play(env)
# env = env.step(r1, c1, symbol1)
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
# r2, c2, symbol2 = human.play(env)
# env = env.step(r2, c2, symbol2)
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
# r1, c1, symbol1 = agent1.play(env)
# env = env.step(r1, c1, symbol1)
# print(env.steps_left, env.is_done())
# env.show_board()

# %%
def human_agent_compete():
    """Human compete with agent."""
    # Get human player.
    human_name = input('Please input your name:\n')
    while True:
        human_player = input('Please input your player: ' + 
                             '1st player (X), 2nd player (O):\n')
        if human_player in ['X', 'O']:
            break

    env = Environment()
    env.show_board()
    print('---')

    # Set up human & agent as player1 or player2.
    if human_player == 'X':
        # Player1: human, player2: agent.
        human, agent = Human(player='X'), Agent(player='O', epsilon=0)
        player1, player2 = human, agent
        player1_name, player2_name = human_name, 'Robot'
    else:
        # Player1: agent, player2: human.
        agent, human = Agent(player='X', epsilon=0), Human(player='O')
        player1, player2 = agent, human
        player1_name, player2_name = 'Robot', human_name
    agent.reset_episode(env)
    agent.load_state_value_table()

    # Start competition.
    while not env.is_done():
        # Player1 plays one step.
        r1, c1, symbol1 = player1.select_position(env)
        env = env.step(r1, c1, symbol1)
        print('Player1, {} ({}), puts ({}, {})'
              .format(player1_name, player1.player, r1, c1))
        env.show_board()
        print('---')

        if env.is_done():
            break

        # Player2 plays the next step.
        r2, c2, symbol2 = player2.select_position(env)
        env = env.step(r2, c2, symbol2)
        print('Player2, {} ({}), puts ({}, {})'
              .format(player2_name, player2.player, r2, c2))
        env.show_board()
        print('---')

    # Judge the winner.
    if env.winner == human.symbol:
        print('Congrats {}, you win!'.format(human_name))
    elif env.winner == -human.symbol:
        print('{} loses to Robot...'.format(human_name))
    else:
        print('{} and Robot tie.'.format(human_name))

# %%
human_agent_compete()
# Out:
# Please input your name:
# Bowen
# Please input your player: 1st player (X), 2nd player (O):
# O
# Board: is_done=False, steps_left=9, winner=0
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# ---
# Player1, Robot (X), puts (2, 0)
# Board: is_done=False, steps_left=8, winner=0
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# ['X', ' ', ' ']
# ---
# Please input position for O in the format: "row,col" with row/col: 0~2:
# 2,2
# Player2, Bowen (O), puts (2, 2)
# Board: is_done=False, steps_left=7, winner=0
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# ['X', ' ', 'O']
# ---
# Player1, Robot (X), puts (0, 0)
# Board: is_done=False, steps_left=6, winner=0
# ['X', ' ', ' ']
# [' ', ' ', ' ']
# ['X', ' ', 'O']
# ---
# Please input position for O in the format: "row,col" with row/col: 0~2:
# 1,0
# Player2, Bowen (O), puts (1, 0)
# Board: is_done=False, steps_left=5, winner=0
# ['X', ' ', ' ']
# ['O', ' ', ' ']
# ['X', ' ', 'O']
# ---
# Player1, Robot (X), puts (0, 2)
# Board: is_done=False, steps_left=4, winner=0
# ['X', ' ', 'X']
# ['O', ' ', ' ']
# ['X', ' ', 'O']
# ---
# Please input position for O in the format: "row,col" with row/col: 0~2:
# 1,1
# Player2, Bowen (O), puts (1, 1)
# Board: is_done=False, steps_left=3, winner=0
# ['X', ' ', 'X']
# ['O', 'O', ' ']
# ['X', ' ', 'O']
# ---
# Player1, Robot (X), puts (0, 1)
# Board: is_done=True, steps_left=0, winner=1
# ['X', 'X', 'X']
# ['O', 'O', ' ']
# ['X', ' ', 'O']
# ---
# Bowen loses to Robot...
